# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
#import seaborn as sns
plt.figure(figsize=[16,16])
plt.subplot(221)
plt.title("圖書分類與銷售比率-男性",fontsize=20)
sizes = [0.14,0.16,0.08,0.13,0.16,0.12,0.16,0.05]
labels = ['商業理財','文學小說','藝術設計','人文科普','語言電腦','心靈養生','生活風格','親子共享']
#colors = ['orange','green','red','purple','brown','pink','grey','blue'] 因為預設的顏色比較好看，所以我不自己設定顏色
plt.pie(sizes,labels = labels, 
        shadow = True, startangle = 0, labeldistance = 1.1,autopct = "%2.1f%%",
       pctdistance = 0.6)
plt.rcParams["font.sans-serif"] = "DFKai-SB"
plt.rcParams["axes.unicode_minus"] = False



plt.subplot(222)
plt.title("Chart 2")
plt.title("圖書分類與銷售比率-女性",fontsize=20)
sizes = [0.1,0.19,0.06,0.1,0.13,0.13,0.2,0.09]
labels = ['商業理財','文學小說','藝術設計','人文科普','語言電腦','心靈養生','生活風格','親子共享']
#colors = ['orange','green','red','purple','brown','pink','grey','blue']
plt.pie(sizes,labels = labels, 
        shadow = True, startangle = 0, labeldistance = 1.1,autopct = "%2.1f%%",
       pctdistance = 0.6)
plt.rcParams["font.sans-serif"] = "DFKai-SB"
plt.rcParams["axes.unicode_minus"] = False

plt.subplot(223)
plt.title("圖書分類銷售長條圖-性別",fontsize=20)
width = 0.25
listx = ['商業理財','文學小說','藝術設計','人文科普','語言電腦','心靈養生','生活風格','親子共享']
listy = ['0%','2.5%','5%','7.5%','10%','12.5%','15%','17.5%','20%']
listx1 = [x - width/2 for x in range(len(listx))]
listx2 = [x + width/2 for x in range(len(listx))]
listy1 = [0.14,0.16,0.08,0.13,0.16,0.12,0.16,0.05]
listy2 = [0.1,0.19,0.06,0.1,0.13,0.13,0.2,0.09]
plt.bar(listx1,listy1,width, label = "男")
plt.bar(listx2,listy2,width, label = "女")
x = [0,1,2,3,4,5,6,7]
y = [0,0.025,0.05,0.075,0.1,0.125,0.15,0.175,0.2]
plt.xticks(x,listx,fontsize=12)
plt.yticks(y,listy,fontsize=12)
plt.xlabel("圖書分類",fontsize=15)
plt.ylabel("銷售比率%",fontsize=15)
plt.rcParams["font.sans-serif"] = "DFKai-SB"
plt.rcParams["axes.unicode_minus"] = False
plt.legend()


plt.subplot(224)
plt.title("圖書分類銷售折線圖-性別",fontsize=20)


listx = ['商業理財','文學小說','藝術設計','人文科普','語言電腦','心靈養生','生活風格','親子共享']
listy = ['0%','2.5%','5%','7.5%','10%','12.5%','15%','17.5%','20%']
listx1 = [x - width/2 for x in range(len(listx))]
listx2 = [x + width/2 for x in range(len(listx))]
listy1 = [0.14,0.16,0.08,0.13,0.16,0.12,0.16,0.05]
listy2 = [0.1,0.19,0.06,0.1,0.13,0.13,0.2,0.09]






plt.plot(listx,listy1,'s-',color = 'r', label="男")


plt.plot(listx,listy2,'o-',color = 'g', label="女")



plt.xticks(fontsize=12)

plt.yticks(fontsize=12)


plt.xlabel("圖書分類",fontsize=15)


plt.ylabel("銷售比率%",fontsize=15)
#sns.set(style = "whitegrid") 
plt.legend()


plt.show()
