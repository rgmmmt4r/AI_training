# %% [markdown]
# # Markdown 語法教學
#
# ---------------------------------------
#
# ## 目錄
# ### CH1 AI 起源
# #### 1-1 遍地開花的AI應用
# #### 1-2 人工智慧的應用
# #### 1-3 人工智慧@台灣
# #### 1-4 未來的AI生活
# ### CH2 應用篇
# #### 2-1 影像處理
#
#
# ----

# %% [markdown]
#  ### Quiz
#  $$F=\sum_{n=1}^{100} (x_n + x_n^2)$$
#
#  ----

# %% [markdown]
#  ### Quiz
#      import os
#      file = "myfile.txt"
#      if os.path.exists(file):
#          os.remove(file)
#          print(file + "is deleted.")
#      else:
#          print(file + "is not found!")
#  ----

# %% [markdown]
# ## Quiz
# ## 目錄
# * ### CH1 AI 起源
#     * #### 1-1 遍地開花的AI應用
#     * #### 1-2 人工智慧的應用
#     * #### 1-3 人工智慧@台灣
#     * #### 1-4 未來的AI生活
# * ### CH2 應用篇
#     * #### 2-1 影像處理
#
# ----

# %% [markdown]
# ### 斜體
# *x + y = Z*
#
# `*x + y = Z*`

# %% [markdown]
# ### double star stands for bold character
# example: `**Inportant concept**`
#
#
# **Inportant concept**

# %% [markdown]
# ### Single money icon stands for math formula
#
# example:
#  `$x^2 + 2x +1$`
#
#
# $x^2 + 2x +1$
#
# --------
#
#
# ### Double money icon stands for centrol math formula
# `$$\int_a^b f(x)\,dx $$`
# $$\int_a^b f(x)\,dx $$
#
# $$ \eta  \theta  \vartheta \lambda  $$

# %% [markdown]
#  $f(x) = ax^n$
#
#  $\frac{df(x)}{dx} = anx^{n-1} $
#
#   $f(x) = 2x^3 + 6xy^2 +4y +2$
#
#  $\frac{ \partial f(x)}{ \partial x}  = 6x^2 + 6y^2 $
#
#   $\frac{ \partial f(x)}{ \partial ｙ}  =  12xy + 4 $

# %% [markdown]
# 多行引號
# ```
# git init
# git add
# git commit
# ```
# 沒打引號
# git init
# git add
# git commit
#
#     控四格縮排也可以
#     git init
#     git add
#     git commit
#     for i in range(10):
#         print(i)

# %% [markdown]
# * 第一點
#     * 第1.1點
#         *第1.1.1點
# * 第二點
# + 第三點
# - 第四點

# %% [markdown]
# ### 數字編號
# 1. 匯出檔案
# 2. 載入檔案
# 3. HTML
# 7. C#
# 4. Python
# 5. C
# 6. Java

# %% [markdown]
# ## 目錄
# * ### CH1 AI 起源
#     1. #### 1-1 遍地開花的AI應用
#     2. #### 1-2 人工智慧的應用
#     3. #### 1-3 人工智慧@台灣
#     4. #### 1-4 未來的AI生活
# * ### CH2 應用篇
#     1. #### 2-1 影像處理
#     2. #### 2-1 自然語言處理

# %% [markdown]
# ![lotus.png](attachment:lotus.png)

# %% [markdown]
# 更多markdown 可以參考:https://markdown.tw/

# %% [markdown]
# ## 檔案、例外處理
# ### 5.11.1 os 模組
# #### 建立目錄
#
# #### getcwd() 函式 可以取得目前工作的目錄、刪除目錄等等

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\rgmmm

# %% [markdown]
# ### remove()
# 先檢查檔案是否存在(用 path)
#
#      import os
#      file = "myfile.txt"
#      if os.path.exists(file):
#          os.remove(file)
#          print(file + "is deleted.")
#      else:
#          print(file + "is not found!")

# %% [markdown]
# #### 現在用小作家增加一個 myFile.txt 檔案

# %%
import os
 file = "myfile.txt"
 if os.path.exists(file):
     os.remove(file)
     print(file + "is deleted.")
 else:
     print(file + "does not be created!")
# Out:
# myfile.txtis deleted.

# %%
 import os
 file = "myfile.txt"
 if os.path.exists(file):
     os.remove(file)
     print(file + "is deleted.")
 else:
     print(file + "does not be created!")
# Out:
# myfile.txtdoes not be created!

# %% [markdown]
# #### mkdir()
#     建立指定的目錄
#     import os
#     os.mkdir("myDir")

# %%
import os
os.mkdir("myDir")

# %% [markdown]
# #### rmdir()
#      建立指定的目錄後，可以使用 rmdir() 去除目錄
#      import os
#      dir = "myDir"
#      if os.path.exists(dir):
#          os.remove(dir)
#          print(dir + "is deleted.")
#      else:
#          print(dir + "is not created!")

# %%
 import os
 dir = "myDir"
 if os.path.exists(dir):
     os.rmdir(dir)
     print(dir + "is deleted.")
 else:
     print(dir + "is not created!")
# Out:
# myDiris deleted.

# %%
 import os
 dir = "myDir"
 if os.path.exists(dir):
     os.rmdir(dir)
     print(dir + "is deleted.")
 else:
     print(dir + "is not created!")
# Out:
# myDiris not created!

# %% [markdown]
# ### 建立 myFile.txt

# %%
import os 
cur_path = os.getcwd()
print(cur_path)
os.system("cls")
os.system("mkdir myDir2")
os.system("copy myFile.txt myDir2\copyfile.txt")
# Out:
# C:\Users\rgmmm
# 0

# %%
file = cur_path +"\myDir2\copyfile.txt"
print(file)
# Out:
# C:\Users\rgmmm\myDir2\copyfile.txt

# %%
os.system("notepad " + file)
# Out:
# 0

# %% [markdown]
# os.path 可以get 完整路徑

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 取得 myFile.txt 路徑的範例如下

# %%
import os.path

cur_path = os.getcwd()
print("The current path:" + cur_path)
# Out:
# The current path:C:\Users\rgmmm

# %%
filename = os.path.abspath("myFile.txt")
print("Full:" + filename)
print("size: ",os.path.getsize(filename))
# Out:
# Full:C:\Users\rgmmm\myFile.txt
# size:  0

# %%
basename = os.path.basename(filename)
print("最後的檔案或路徑名稱:" + basename)
# Out:
# 最後的檔案或路徑名稱:myFile.txt

# %%
dirname = os.path.dirname(filename)
print("目前檔案目錄路徑: " + dirname)
print("是否為目錄:", os.path.isdir(filename))
# Out:
# 目前檔案目錄路徑: C:\Users\rgmmm
# 是否為目錄: False

# %%
fullpath,fname = os.path.split(filename)
print("目錄路徑: " + fullpath)
print("檔名: " + fname)
# Out:
# 目錄路徑: C:\Users\rgmmm
# 檔名: myFile.txt

# %%
Drive, fpath = os.path.splitdrive(filename)
print("Drive: "+ Drive)
print("path: " + fpath)
# Out:
# Drive: C:
# path: \Users\rgmmm\myFile.txt

# %%
fullpath = os.path.join(Drive,"\\",fpath)
print(fullpath)
# Out:
# C:\Users\rgmmm\myFile.txt

# %%
import os
cur_path = os.getcwd()
sample_tree = os.walk(cur_path)
for dirname, subdir,files in sample_tree:
    print("檔案路徑: ",dirname)
    print("subpath: ",subdir)
    print("Files: ",files)
    print()

# %%
import os
cur_path = os.getcwd()
print(cur_path)
# Out:
# C:\Users\rgmmm

# %% [markdown]
# ## shutil 用法
#
# ![image.png](attachment:image.png)!
#
# 以下例子是複製一個檔案

# %%
import os, shutil
cur_path = os.getcwd()
destfile = cur_path + "\\" +"newfile.txt"
shutil.copy("myfile.txt",destfile)
# Out:
# 'C:\\Users\\rgmmm\\newfile.txt'

# %% [markdown]
# ## glob 模組
# 找出路徑下的檔案，如下例子

# %%
import glob
files = glob.glob("01.py") + glob.glob("os*.py") + glob.glob("*.txt")
for file in files:
    print(file)
# Out:
# 01.py
# ospath.py
# myFile.txt
# newfile.txt

# %% [markdown]
# ## open
#
# ![image.png](attachment:image.png)
#
# 如下例子:open('file1.txt','w')

# %%
content ='''Hello Python
中文字測試
Welcome
'''
f = open('file1.txt','w')
f.write(content)
f.close()

# %%
f = open('file1.txt','r')
for line in f:
    print(line , end = '')
f.close()
# Out:
# Hello Python
# 中文字測試
# Welcome

# %% [markdown]
# 使用 with open 可以自動close掉

# %%
with open('file1.txt','r') as f:
    for line in f:
        print(line , end = '')
# Out:
# Hello Python
# 中文字測試
# Welcome

# %% [markdown]
# ###  read處理檔案的方法
# ![image-2.png](attachment:image-2.png)

# %%
f = open('file1.txt','r')
str1 = f.read(5)
print(str1)
f.close()
# Out:
# Hello

# %%
with open('file1.txt','r') as f:
    content = f.readlines()
    print(type(content))
    print(content)
# Out:
# <class 'list'>
# ['Hello Python\n', '中文字測試\n', 'Welcome\n']

# %% [markdown]
# 讀取UTF8

# %%
with open('file2.txt','r',encoding = 'UTF-8') as f:
    context = f.readlines()
    print(content)
# Out:
# ['Hello Python\n', '中文字測試\n', 'Welcome\n']

# %% [markdown]
# 使用BOM 的 UTF8

# %%
with open('file1.txt','r',encoding = 'UTF-8-sig') as f:
    context = f.readlines()
    print(content)
# Out:
# ['Hello Python\n', '中文字測試\n', 'Welcome\n']

# %% [markdown]
# ## ast 套件:文字轉成字典

# %%
import ast
data = dict()
with open("password.txt",'r',encodeing = "UTF-8-sig") as f:

# %% [markdown]
# ## 帳密管理
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)![image-3.png](attachment:image-3.png)![image-4.png](attachment:image-4.png)![image-5.png](attachment:image-5.png)

# %% [markdown]
#  實作:
#
#
#  **可以建立、查詢、修改、刪除 帳號密碼的程式**

# %%
def delete_data():
    while True:
        name = input("請輸入刪除的帳號(Enter==>停止輸入)")
        if name == '': break
        if name not in data:
            print("{}帳號不存在".format(name))
            continue
        else:
            print("確定刪除{}嗎".format(name))
            confirm = input("y/n")
            if confirm == "y":
                del data[name]
                with open("password.txt","w",encoding = "UTF-8-sig") as f:
                    f.write(str(data))
                    input("帳號已成功刪除，請輸入任意鍵返回主選單")
                    break

# %%
def disp_data():
    for name in data:
        print("帳號\t密碼 ")
        print("-----------------------------")
        for key in data:
            print("{}\t{}".format(key,data[key]))
        input("按任意鍵返回主選單")

# %%
def edit_data():
    while True:
        name = input("請輸入修改的帳號(Enter==>停止輸入)")
        if name == '': break
        if name not in data:
            print("{}帳號不存在".format(name))
            continue
        else:
            print("原來密碼為:{}".format(data[name]))
            password = input("請輸入新密碼")
            data[name] = password
            with open("password.txt","w",encoding = "UTF-8-sig") as f:
                f.write(str(data))
                input("密碼已更改完畢，請輸入任意鍵返回主選單")
                break

# %%
def input_data():
    while True:
        name = input("請輸入帳號(Enter==>停止輸入)")
        if name =='':break
        if name in data:
            print("{}帳號已存在".format(name))
            continue
        password = input("請輸入密碼")
        data[name] = password
        with open("password.txt","w",encoding = "UTF-8-sig") as f:
            f.write(str(data))
        print("{}已被儲存完畢".format(name))

# %%
def menu():
    os.system("cls")
    print("帳號、密碼管理系統")
    print("-----------------------------")
    print("1. 新增帳號、密碼")
    print("2. 顯示帳號、密碼")
    print("3. 修  改  密 碼")
    print("4. 刪除帳號、密碼")
    print("0. 結  束  程 式")
    print("-----------------------------")

# %%
def ReadData():
    with open('password.txt','r',encoding = 'UTF-8-sig') as f:
        filedata = f.read()
        if filedata != '':
            data = ast.literal_eval(filedata)
            return data
        else:
            return dict()

# %%
import os,ast
data = dict()
data = ReadData()
menu()
input_data()
disp_data()
#edit_data()
delete_data()
# Out:
# 帳號、密碼管理系統
# -----------------------------
# 1. 新增帳號、密碼
# 2. 顯示帳號、密碼
# 3. 修  改  密 碼
# 4. 刪除帳號、密碼
# 0. 結  束  程 式
# -----------------------------
# 請輸入帳號(Enter==>停止輸入)
# 請輸入刪除的帳號(Enter==>停止輸入)

# %%
import os,ast
data = dict()
data = ReadData()
while True:
    menu()
    choice = int(input("請輸入您的選擇"))
    print()
    if choice == 1:
        input_data()
    elif choice == 2:
        disp_data()
    elif choice == 3:
        edit_data()
    elif choice == 4:
        delete_data()
    else:
        break
print("程式執行完畢!")
# Out:
# 帳號、密碼管理系統
# -----------------------------
# 1. 新增帳號、密碼
# 2. 顯示帳號、密碼
# 3. 修  改  密 碼
# 4. 刪除帳號、密碼
# 0. 結  束  程 式
# -----------------------------
# 請輸入您的選擇1
#
# 請輸入帳號(Enter==>停止輸入)Eddie
# 請輸入密碼13
# Eddie已被儲存完畢
# 請輸入帳號(Enter==>停止輸入)2
# 請輸入密碼2
# 2已被儲存完畢
# 請輸入帳號(Enter==>停止輸入)
# 帳號、密碼管理系統
# -----------------------------
# 1. 新增帳號、密碼
# 2. 顯示帳號、密碼
# 3. 修  改  密 碼
# 4. 刪除帳號、密碼
# 0. 結  束  程 式
# -----------------------------
# 請輸入您的選擇2
#
# 帳號	密碼
# -----------------------------
# Eddie	13
# 2	2
# 按任意鍵返回主選單
# 帳號	密碼
# -----------------------------
# Eddie	13
# 2	2
# 按任意鍵返回主選單3
# 帳號、密碼管理系統
# -----------------------------
# 1. 新增帳號、密碼
# 2. 顯示帳號、密碼
# 3. 修  改  密 碼
# 4. 刪除帳號、密碼
# 0. 結  束  程 式
# -----------------------------
# 請輸入您的選擇3
#
# 請輸入修改的帳號(Enter==>停止輸入)Eddie
# 原來密碼為:13
# 請輸入新密碼14
# 密碼已更改完畢，請輸入任意鍵返回主選單
# 帳號、密碼管理系統
# -----------------------------
# 1. 新增帳號、密碼
# 2. 顯示帳號、密碼
# 3. 修  改  密 碼
# 4. 刪除帳號、密碼
# 0. 結  束  程 式
# -----------------------------
# 請輸入您的選擇4
#
# 請輸入刪除的帳號(Enter==>停止輸入)Eddie
# ...
